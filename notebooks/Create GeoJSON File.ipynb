# %%
import os
import xml.etree.ElementTree as ET
import json
import re
import datetime
import exifread

# %%
gpx_file_names = [x for x in os.listdir('../assets/gps_tracks') if x.endswith('gpx')]
#gpx_file_names = ['d10_01_ride.gpx']
gpx_files = [os.path.join('../assets/gps_tracks', x) for x in gpx_file_names]
gpx_file_names[0]
# Out:
# 'd01_01_ride.gpx'

# %%
all_coordinates = []
properties = []

one_list_coords = []
one_list_times = []

def append_to_properties(properties, day, section, category):
    properties.append({
        "day": day,
        "section": section,
        "category": category
    })

previous_day = 0
for gpx_file, gpx_file_name in zip(gpx_files, gpx_file_names):
    parts = gpx_file_name.split('_')
    day = int(parts[0][1:])
    if day != previous_day:
        section = 1
    previous_day = day
    exercise_type = parts[2].split('.')[0]
    
    
    tree = ET.parse(gpx_file)
    root = tree.getroot()

    trk = [c for c in root if c.tag.endswith('trk')]
    trksegs = [t for t in trk[0] if t.tag.endswith('trkseg')]
    trkpts = []

    for trkseg in trksegs:
        trkpts.extend([p for p in trkseg if p.tag.endswith('trkpt')])
    coordinates = [(float(t.attrib['lon']), float(t.attrib['lat'])) for t in trkpts]
    times = [datetime.datetime.strptime([t for t in x if t.tag.endswith('time')][0].text, "%Y-%m-%dT%H:%M:%SZ") for x in trkpts]
    one_list_coords.extend(coordinates)
    one_list_times.extend(times)
    
    last_idx = 0
    for c0, c1, i in zip(coordinates[:-1], coordinates[1:], range(len(coordinates)-1)):
        d2 = (c1[1] - c0[1])**2 + (c1[0] - c0[0])**2
        if d2 > 0.03**2:
            all_coordinates.append(coordinates[last_idx:i+1])
            last_idx = i+1
            append_to_properties(properties, day, section, exercise_type)
            section += 1
    
    if last_idx < len(coordinates):
        all_coordinates.append(coordinates[last_idx:])
        append_to_properties(properties, day, section, exercise_type)
        section += 1

# %% [markdown]
# ## Photo time alignment

# %%
photo_file_names = [x for x in os.listdir('../assets/images/Scotland2018') if x.endswith('.JPG') and not x.endswith('Thumb.JPG')]
photo_files = [os.path.join('../assets/images/Scotland2018', x) for x in photo_file_names]
photo_file_names[0]
# Out:
# 'P1020191.JPG'

# %%
photo_properties = {}
photo_times = {}
for i, file_path, file_name in zip(range(len(photo_files)), photo_files, photo_file_names):

    with open(file_path, 'rb') as f:
        # Return Exif tags
        tags = exifread.process_file(f)

    photo_times[file_name] = datetime.datetime.strptime(tags['EXIF DateTimeOriginal'].values, "%Y:%m:%d %H:%M:%S")
    photo_properties[file_name] = {
        'time_taken': datetime.datetime.strftime(photo_times[file_name], "%a %d %b %Y %H:%M"),
        'file_name': file_name,
        'id': i
    }

photo_times
# Out:
# {'P1020191.JPG': datetime.datetime(2018, 7, 16, 11, 34),
#  'P1020192.JPG': datetime.datetime(2018, 7, 16, 12, 11, 59),
#  'P1020193.JPG': datetime.datetime(2018, 7, 16, 12, 43, 58),
#  'P1020194.JPG': datetime.datetime(2018, 7, 16, 12, 44, 14),
#  'P1020195.JPG': datetime.datetime(2018, 7, 16, 12, 48, 29),
#  'P1020196.JPG': datetime.datetime(2018, 7, 16, 12, 48, 48),
#  'P1020238.JPG': datetime.datetime(2018, 7, 24, 7, 27, 55),
#  'P1020239.JPG': datetime.datetime(2018, 7, 24, 9, 6, 29),
#  'P1020240.JPG': datetime.datetime(2018, 7, 24, 10, 58, 46),
#  'P1020241.JPG': datetime.datetime(2018, 7, 24, 10, 59, 51),
#  'P1020242.JPG': datetime.datetime(2018, 7, 24, 12, 54, 55),
#  'P1020243.JPG': datetime.datetime(2018, 7, 24, 12, 55, 8),
#  'P1020244.JPG': datetime.datetime(2018, 7, 24, 13, 35, 11),
#  'P1020245.JPG': datetime.datetime(2018, 7, 24, 14, 52, 14),
#  'P1020246.JPG': datetime.datetime(2018, 7, 24, 16, 50, 17),
#  'P1020248.JPG': datetime.datetime(2018, 7, 24, 18, 7, 37),
#  'P1020249.JPG': datetime.datetime(2018, 7, 24, 20, 12, 16),
#  'P1020251.JPG': datetime.datetime(2018, 7, 24, 20, 12, 38),
#  'P1020252.JPG': datetime.datetime(2018, 7, 24, 20, 12, 57),
#  'P1020253.JPG': datetime.datetime(2018, 7, 24, 20, 15, 8),
#  'P1020254.JPG': datetime.datetime(2018, 7, 24, 20, 15, 33),
#  'P1020256.JPG': datetime.datetime(2018, 7, 24, 20, 35, 20),
#  'P1020257.JPG': datetime.datetime(2018, 7, 24, 20, 35, 25),
#  'P1020258.JPG': datetime.datetime(2018, 7, 24, 20, 35, 52),
#  'P1020259.JPG': datetime.datetime(2018, 7, 25, 9, 42, 56),
#  'P1020260.JPG': datetime.datetime(2018, 7, 25, 11, 55, 24),
#  'P1020261.JPG': datetime.datetime(2018, 7, 25, 12, 2, 23),
#  'P1020262.JPG': datetime.datetime(2018, 7, 25, 14, 7, 43),
#  'P1020265.JPG': datetime.datetime(2018, 7, 25, 15, 27, 34),
#  'P1020266.JPG': datetime.datetime(2018, 7, 25, 18, 28, 49),
#  'P1020267.JPG': datetime.datetime(2018, 7, 25, 18, 56, 51),
#  'P1020268.JPG': datetime.datetime(2018, 7, 25, 18, 57, 5),
#  'P1020269.JPG': datetime.datetime(2018, 7, 26, 4, 36, 26),
#  'P1020271.JPG': datetime.datetime(2018, 7, 26, 4, 45, 26),
#  'P1020272.JPG': datetime.datetime(2018, 7, 26, 4, 56, 41),
#  'P1020273.JPG': datetime.datetime(2018, 7, 26, 5, 11, 30),
#  'P1020274.JPG': datetime.datetime(2018, 7, 26, 5, 49, 56),
#  'P1020275.JPG': datetime.datetime(2018, 7, 26, 5, 50, 21),
#  'P1020276.JPG': datetime.datetime(2018, 7, 26, 11, 15, 35),
#  'P1020277.JPG': datetime.datetime(2018, 7, 26, 12, 22, 26),
#  'P1020278.JPG': datetime.datetime(2018, 7, 26, 12, 41, 6),
#  'P1020279.JPG': datetime.datetime(2018, 7, 26, 18, 45, 26),
#  'P1020280.JPG': datetime.datetime(2018, 7, 26, 19, 50, 27),
#  'P1020282.JPG': datetime.datetime(2018, 7, 26, 21, 29, 8),
#  'P1020284.JPG': datetime.datetime(2018, 7, 27, 8, 28, 2),
#  'P1020286.JPG': datetime.datetime(2018, 7, 27, 8, 53, 38),
#  'P1020288.JPG': datetime.datetime(2018, 7, 27, 8, 55, 16),
#  'P1020289.JPG': datetime.datetime(2018, 7, 27, 18, 2, 36),
#  'P1020290.JPG': datetime.datetime(2018, 7, 27, 18, 3, 4),
#  'P1020291.JPG': datetime.datetime(2018, 7, 27, 18, 34, 9),
#  'P1020292.JPG': datetime.datetime(2018, 7, 28, 10, 3, 10),
#  'P1020293.JPG': datetime.datetime(2018, 7, 28, 12, 40, 57),
#  'P1020294.JPG': datetime.datetime(2018, 7, 28, 12, 45, 25),
#  'P1020295.JPG': datetime.datetime(2018, 7, 28, 17, 10, 28),
#  'P1020296.JPG': datetime.datetime(2018, 7, 28, 17, 19, 7),
#  'P1020297.JPG': datetime.datetime(2018, 7, 28, 19, 37, 23),
#  'P1020300.JPG': datetime.datetime(2018, 7, 28, 20, 4, 57),
#  'P1020301.JPG': datetime.datetime(2018, 7, 28, 20, 13, 46),
#  'P1020302.JPG': datetime.datetime(2018, 7, 28, 20, 13, 52),
#  'P1020303.JPG': datetime.datetime(2018, 7, 29, 10, 51, 9),
#  'P1020304.JPG': datetime.datetime(2018, 7, 29, 12, 56, 5),
#  'P1020305.JPG': datetime.datetime(2018, 7, 29, 14, 56, 38),
#  'P1020306.JPG': datetime.datetime(2018, 7, 29, 15, 3, 5),
#  'P1020308.JPG': datetime.datetime(2018, 7, 29, 15, 32, 26),
#  'P1020309.JPG': datetime.datetime(2018, 7, 29, 15, 56, 1),
#  'P1020310.JPG': datetime.datetime(2018, 7, 29, 16, 23, 16),
#  'P1020312.JPG': datetime.datetime(2018, 7, 29, 17, 50, 37),
#  'P1020316.JPG': datetime.datetime(2018, 7, 29, 18, 4, 4),
#  'P1020317.JPG': datetime.datetime(2018, 7, 29, 18, 4, 50),
#  'P1020319.JPG': datetime.datetime(2018, 7, 29, 19, 6, 17),
#  'P1020320.JPG': datetime.datetime(2018, 7, 29, 19, 6, 36),
#  'P1020323.JPG': datetime.datetime(2018, 7, 29, 20, 32, 41),
#  'P1020324.JPG': datetime.datetime(2018, 7, 30, 8, 12, 37),
#  'P1020325.JPG': datetime.datetime(2018, 7, 30, 12, 56, 11),
#  'P1020328.JPG': datetime.datetime(2018, 7, 30, 12, 59, 26),
#  'P1020331.JPG': datetime.datetime(2018, 7, 30, 15, 40, 25),
#  'P1020332.JPG': datetime.datetime(2018, 7, 30, 16, 12, 45),
#  'P1020333.JPG': datetime.datetime(2018, 7, 30, 16, 29, 46),
#  'P1020334.JPG': datetime.datetime(2018, 7, 30, 17, 39, 42),
#  'P1020336.JPG': datetime.datetime(2018, 7, 30, 18, 17, 56),
#  'P1020337.JPG': datetime.datetime(2018, 7, 30, 18, 18, 31),
#  'P1020346.JPG': datetime.datetime(2018, 7, 30, 18, 20, 4),
#  'P1020347.JPG': datetime.datetime(2018, 7, 30, 18, 20, 48),
#  'P1020349.JPG': datetime.datetime(2018, 7, 30, 18, 21),
#  'P1020350.JPG': datetime.datetime(2018, 7, 30, 18, 24, 35),
#  'P1020351.JPG': datetime.datetime(2018, 7, 30, 20, 43, 25),
#  'P1020353.JPG': datetime.datetime(2018, 7, 30, 20, 51, 5),
#  'P1020354.JPG': datetime.datetime(2018, 7, 31, 6, 10, 46),
#  'P1020358.JPG': datetime.datetime(2018, 7, 31, 10, 14, 8),
#  'P1020359.JPG': datetime.datetime(2018, 7, 31, 11, 51, 50),
#  'P1020362.JPG': datetime.datetime(2018, 7, 31, 14, 42, 49),
#  'P1020363.JPG': datetime.datetime(2018, 8, 1, 9, 35, 15),
#  'P1020364.JPG': datetime.datetime(2018, 8, 1, 9, 36, 20),
#  'P1020366.JPG': datetime.datetime(2018, 8, 1, 9, 55, 13),
#  'P1020369.JPG': datetime.datetime(2018, 8, 1, 10, 8, 52),
#  'P1020372.JPG': datetime.datetime(2018, 8, 2, 9, 3, 37),
#  'P1020374.JPG': datetime.datetime(2018, 8, 2, 9, 25, 7),
#  'P1020380.JPG': datetime.datetime(2018, 8, 2, 9, 59, 48),
#  'P1020381.JPG': datetime.datetime(2018, 8, 2, 11, 6, 22),
#  'P1020382.JPG': datetime.datetime(2018, 8, 2, 11, 43, 51),
#  'P1020383.JPG': datetime.datetime(2018, 8, 2, 12, 18, 4),
#  'P1020384.JPG': datetime.datetime(2018, 8, 3, 6, 13, 10),
#  'P1020386.JPG': datetime.datetime(2018, 8, 3, 9, 20, 11),
#  'P1020387.JPG': datetime.datetime(2018, 8, 3, 10, 39, 54),
#  'P1020388.JPG': datetime.datetime(2018, 8, 3, 13, 36, 53)}

# %% [markdown]
# ### Match to nearest location

# %%
geotags = {}
for file_name, date_taken in photo_times.items():
    min_idx = 0
    min_d = datetime.timedelta(days=400)
    for i,t in enumerate(one_list_times):
        d = abs(date_taken - t)
        if d < min_d:
            min_d = d
            min_idx = i
    geotags[file_name] = one_list_coords[min_idx]

# %%
geotags
# Out:
# {'P1020191.JPG': (-4.583887, 56.003128),
#  'P1020192.JPG': (-4.619849, 56.020494),
#  'P1020193.JPG': (-4.636852, 56.10197),
#  'P1020194.JPG': (-4.636852, 56.10197),
#  'P1020195.JPG': (-4.636852, 56.10197),
#  'P1020196.JPG': (-4.636852, 56.10197),
#  'P1020197.JPG': (-4.709587, 56.202661),
#  'P1020198.JPG': (-4.709587, 56.202661),
#  'P1020199.JPG': (-4.709587, 56.202661),
#  'P1020200.JPG': (-4.709587, 56.202661),
#  'P1020201.JPG': (-4.536336, 56.209051),
#  'P1020202.JPG': (-4.536336, 56.209051),
#  'P1020203.JPG': (-4.586909, 56.249542),
#  'P1020204.JPG': (-4.51279, 56.259658),
#  'P1020205.JPG': (-4.428034, 56.227523),
#  'P1020206.JPG': (-4.428034, 56.227523),
#  'P1020207.JPG': (-4.428159, 56.227504),
#  'P1020208.JPG': (-4.428159, 56.227504),
#  'P1020209.JPG': (-4.428159, 56.227504),
#  'P1020210.JPG': (-4.428159, 56.227504),
#  'P1020211.JPG': (-4.442399, 56.346365),
#  'P1020212.JPG': (-4.291234, 56.380274),
#  'P1020384.JPG': (-5.160055, 57.894866),
#  'P1020386.JPG': (-5.119264, 57.879201),
#  'P1020387.JPG': (-4.879084, 57.721475),
#  'P1020388.JPG': (-4.229456, 57.499085)}

# %%
geojson = {
    "type": "FeatureCollection",
    "features": [
        {
            "type": "Feature",
            "geometry": {
                "type": "LineString",
                "coordinates": c
            },
            "properties": p
        } for c,p in zip(all_coordinates, properties)]
}

geojson['features'].extend([
    {
        "type": "Feature",
        "geometry": {
            "type": "Point",
            "coordinates": c
        },
        "properties": photo_properties[file_name]
    } for file_name, c in geotags.items()])

# %% [markdown]
# ## Write geojson string and remove quotes from numbers

# %%
geojson_string = json.dumps(geojson)

new_string = re.sub(r'"(-?\d+(.\d+)?)"', lambda x: x.group(1), geojson_string)
new_string[:2000]
# Out:
# '{"type": "FeatureCollection", "features": [{"type": "Feature", "geometry": {"type": "LineString", "coordinates": [[-1.121485, 52.37534], [-1.12135, 52.375283], [-1.121242, 52.375179], [-1.121699, 52.374698], [-1.121975, 52.374476], [-1.122574, 52.37406], [-1.122717, 52.373991], [-1.122841, 52.374], [-1.122974, 52.374048], [-1.123733, 52.374372], [-1.124551, 52.374709], [-1.124903, 52.374847], [-1.125696, 52.375096], [-1.125952, 52.375169], [-1.126611, 52.375347], [-1.127479, 52.375538], [-1.127758, 52.375568], [-1.127845, 52.375585], [-1.128019, 52.375631], [-1.12857, 52.375922], [-1.128654, 52.376006], [-1.128709, 52.376095], [-1.128761, 52.376286], [-1.128761, 52.376286], [-1.128761, 52.376286], [-1.129033, 52.37838], [-1.129179, 52.378598], [-1.129325, 52.378816], [-1.129618, 52.379251], [-1.129643, 52.379363], [-1.129669, 52.379474], [-1.129694, 52.379586], [-1.12972, 52.379697], [-1.129874, 52.380365], [-1.130051, 52.380477], [-1.13028, 52.380515], [-1.130508, 52.380554], [-1.130737, 52.380592], [-1.134168, 52.381166], [-1.134621, 52.381181], [-1.135318, 52.381177], [-1.135884, 52.381183], [-1.135884, 52.381183], [-1.140694, 52.382068], [-1.141015, 52.382149], [-1.141481, 52.382304], [-1.14156, 52.38234], [-1.141913, 52.382546], [-1.142235, 52.382815], [-1.1426, 52.382902], [-1.142964, 52.382988], [-1.143329, 52.383075], [-1.143694, 52.383161], [-1.146978, 52.383939], [-1.14787, 52.384074], [-1.14787, 52.384074], [-1.152412, 52.384908], [-1.153237, 52.385141], [-1.154121, 52.385254], [-1.154121, 52.385254], [-1.158713, 52.38568], [-1.159632, 52.385759], [-1.160521, 52.385842], [-1.160521, 52.385842], [-1.165371, 52.386011], [-1.166268, 52.386001], [-1.167152, 52.386045], [-1.167152, 52.386045], [-1.167152, 52.386045], [-1.17124, 52.386817], [-1.171873, 52.386945], [-1.173689, 52.387173], [-1.173922, 52.387188], [-1.174404, 52.387245], [-1.174732, 52.387307], [-1.174732, 52.387307], [-1.174732, 52.387307], [-1.177756, 52.388509], [-1.177756, 52.388509], [-1.1777'

# %%
with open('../assets/gps_tracks/all_tracks.json', 'w') as f:
    f.write(new_string)
